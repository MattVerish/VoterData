# %%
#Import pandas and numpy
import pandas as pd
import numpy as np

# %%
#dataVH = pd.read_csv('Data/WI-Federal-5-VH.csv') #Load VH dataset into a dataframe object
#dataVF = pd.read_csv('Data/WI-Federal-5-VF.csv') #Load VF dataset into a dataframe object

#merged = pd.merge(dataVF, dataVH, on='state_file_id') #Merge records into one dataframe based on state id

# %%
#Create list of election dates
novElec_2016 = np.datetime64('2016-11-08')
novElec_2014 = np.datetime64('2014-11-04')
aprilElec_2015 = np.datetime64('2015-04-07')
febElec_2017 = np.datetime64('2017-02-21')
election_dates = [novElec_2016, novElec_2014, aprilElec_2015]

# %%
#Change date strings into datetime objects for easier comparison
#merged['election_at'] = merged['election_at'].astype('datetime64[ns]') 

#Filter out everyone who did not vote in all elections contained in our list
#filtered = merged.groupby('state_file_id').filter(lambda x: all(day in x['election_at'].values for day in election_dates))

# %%
#Drop duplicate people entried and duplicate addresses
#filtered = merged.drop_duplicates(subset = 'state_file_id')
#filtered = filtered.drop_duplicates(subset = ['registered_address1', 'registered_address2'])
#filtered.shape

# %%
#filtered = pd.read_csv('Data/FilteredData.csv')
filtered = pd.read_csv('Data/FilteredData.csv')

# %%
filtered.shape
# Out:
# (67512, 113)

# %%
LatLongs = []

# %%
for index, address in addresses.iterrows():
    info = address.tolist()
    try:
        zipCode = int(info[4][:6])
    except TypeError:
        continue
    try:
        latLongInfo = ZipCodeLats.loc[ZipCodeLats['ZIP'] == zipCode].as_matrix()[0]
        LatLongs.append((latLongInfo[1], latLongInfo[2]))
    except IndexError:
        continue
len(LatLongs)
# Out:
# 67304

# %%
import googlemaps
gMap = googlemaps.Client(key="AIzaSyA1X4aECu1LiYDZcE4YJ23sjysKNDHl5YU")

# %%
addresses = []
for index, row in filtered.iterrows():
    newString = row['registered_address1'] + ", " + row['registered_city'] + ", WI, " + row['registered_zip']
    addresses.append(newString)

# %%
filtered['location'] = np.nan

# %%
filtered['location']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 67482   NaN
# 67483   NaN
# 67484   NaN
# 67485   NaN
# 67486   NaN
# 67487   NaN
# 67488   NaN
# 67489   NaN
# 67490   NaN
# 67491   NaN
# 67492   NaN
# 67493   NaN
# 67494   NaN
# 67495   NaN
# 67496   NaN
# 67497   NaN
# 67498   NaN
# 67499   NaN
# 67500   NaN
# 67501   NaN
# 67502   NaN
# 67503   NaN
# 67504   NaN
# 67505   NaN
# 67506   NaN
# 67507   NaN
# 67508   NaN
# 67509   NaN
# 67510   NaN
# 67511   NaN
# Name: location, Length: 67512, dtype: float64

# %%
for i in range(10):
    row = filtered.iloc[i]
# Out:
# Unnamed: 0                                                     5011
# nationbuilder_id_x                                          3381619
# state_file_id                                           1.42396e+07
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                   Jean
# middle_name                                                       C
# last_name_x                                                Peterson
# suffix                                                          NaN
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                             2627865821
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                          17285 W River Birch Dr
# registered_address2                                         Apt 111
# registered_address3                                             NaN
# registered_city                                          Brookfield
# registered_county                                          Waukesha
# registered_state                                                 WI
# registered_zip                                           53045-3483
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                      17285
# registered_street_prefix                                          W
# registered_street_name                                  River Birch
# registered_street_type                                           Dr
# registered_street_suffix                                        NaN
# registered_unit_number                                          111
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  04/09/1925
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            03/27/2015
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                    True
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3381619
# voter_guid                     45437d60-0105-11e2-8850-275ed2651afb
# county_file_id_y                                                NaN
# first_name_y                                                   Jean
# last_name_y                                                Peterson
# registered_address_state                                         WI
# registered_address_county                                  Waukesha
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                         absentee
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 0, Length: 113, dtype: object
# Unnamed: 0                                                    13888
# nationbuilder_id_x                                          3435476
# state_file_id                                           7.03119e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                Timothy
# middle_name                                                    Paul
# last_name_x                                               Mcquiston
# suffix                                                          NaN
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                             2622690089
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                                   450 S Lake St
# registered_address2                                           Apt 5
# registered_address3                                             NaN
# registered_city                                          Hustisford
# registered_county                                             Dodge
# registered_state                                                 WI
# registered_zip                                           53034-9765
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                        450
# registered_street_prefix                                          S
# registered_street_name                                         Lake
# registered_street_type                                           St
# registered_street_suffix                                        NaN
# registered_unit_number                                            5
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  10/22/1951
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            02/16/2016
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3435476
# voter_guid                     0e74da22-0105-11e2-bc57-b34b1715f2e5
# county_file_id_y                                                NaN
# first_name_y                                                Timothy
# last_name_y                                               Mcquiston
# registered_address_state                                         WI
# registered_address_county                                     Dodge
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                         absentee
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 1, Length: 113, dtype: object
# Unnamed: 0                                                    14819
# nationbuilder_id_x                                          3437720
# state_file_id                                           7.08443e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                              Christina
# middle_name                                                     Joy
# last_name_x                                               Schwechel
# suffix                                                          NaN
# email                                   christy.schwechel@gmail.com
# email_opt_in                                                  False
# phone_number                                             2622240641
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                             False
# registered_address1                                5397 County Rd E
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                             Slinger
# registered_county                                        Washington
# registered_state                                                 WI
# registered_zip                                                53086
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                       5397
# registered_street_prefix                                        NaN
# registered_street_name                                       County
# registered_street_type                                           Rd
# registered_street_suffix                                          E
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                         NaN
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            11/04/2008
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3437720
# voter_guid                     189f3c18-0105-11e2-a0e7-e37c17147ee8
# county_file_id_y                                                NaN
# first_name_y                                              Christina
# last_name_y                                               Schwechel
# registered_address_state                                         WI
# registered_address_county                                Washington
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 2, Length: 113, dtype: object
# Unnamed: 0                                                    23425
# nationbuilder_id_x                                          3439520
# state_file_id                                            1.4291e+07
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                   Mart
# middle_name                                                   Allen
# last_name_x                                                   Olson
# suffix                                                          NaN
# email                                             Martolson@Aol.Com
# email_opt_in                                                  False
# phone_number                                             2626462409
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                             False
# registered_address1                                    840 Park Way
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                           Delafield
# registered_county                                          Waukesha
# registered_state                                                 WI
# registered_zip                                                53018
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                        840
# registered_street_prefix                                        NaN
# registered_street_name                                         Park
# registered_street_type                                          Way
# registered_street_suffix                                        NaN
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  05/29/1941
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            09/01/2015
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3439520
# voter_guid                     098e3c06-0105-11e2-804e-7b9866f30ac4
# county_file_id_y                                                NaN
# first_name_y                                                   Mart
# last_name_y                                                   Olson
# registered_address_state                                         WI
# registered_address_county                                  Waukesha
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                         absentee
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 3, Length: 113, dtype: object
# Unnamed: 0                                                    69304
# nationbuilder_id_x                                          3907091
# state_file_id                                           7.00227e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                 Taylor
# middle_name                                                 Gillain
# last_name_x                                                   Bauer
# suffix                                                          NaN
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                             7156892472
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                             291 N Fraternity Ln
# registered_address2                                         Apt 301
# registered_address3                                             NaN
# registered_city                                          Whitewater
# registered_county                                          Walworth
# registered_state                                                 WI
# registered_zip                                           53190-1251
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                        291
# registered_street_prefix                                          N
# registered_street_name                                   Fraternity
# registered_street_type                                           Ln
# registered_street_suffix                                        NaN
# registered_unit_number                                          301
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  01/17/1964
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            04/04/2006
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3907091
# voter_guid                     5ebaf85e-0105-11e2-8f50-2347251719c2
# county_file_id_y                                                NaN
# first_name_y                                                 Taylor
# last_name_y                                                   Bauer
# registered_address_state                                         WI
# registered_address_county                                  Walworth
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2017-02-21
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 4, Length: 113, dtype: object
# Unnamed: 0                                                    69358
# nationbuilder_id_x                                          3911631
# state_file_id                                           7.00014e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                   Trey
# middle_name                                                   David
# last_name_x                                                  Jahnke
# suffix                                                          NaN
# email                                            Jahnketd05@Uww.Edu
# email_opt_in                                                  False
# phone_number                                           920-248-0397
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                               1409 Wedgewood Dr
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                           Watertown
# registered_county                                             Dodge
# registered_state                                                 WI
# registered_zip                                           53098-3406
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                       1409
# registered_street_prefix                                        NaN
# registered_street_name                                    Wedgewood
# registered_street_type                                           Dr
# registered_street_suffix                                        NaN
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  02/05/1960
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            02/16/2016
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3911631
# voter_guid                     0b4c913c-0105-11e2-b4c4-0b6701403e17
# county_file_id_y                                                NaN
# first_name_y                                                   Trey
# last_name_y                                                  Jahnke
# registered_address_state                                         WI
# registered_address_county                                     Dodge
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-08-09
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 5, Length: 113, dtype: object
# Unnamed: 0                                                    69379
# nationbuilder_id_x                                          3912205
# state_file_id                                           7.00052e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                  Paula
# middle_name                                                  Carley
# last_name_x                                                Anderson
# suffix                                                          NaN
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                           262-343-2806
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                             False
# registered_address1                                7406 Townline Rd
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                           West Bend
# registered_county                                        Washington
# registered_state                                                 WI
# registered_zip                                                53090
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                       7406
# registered_street_prefix                                        NaN
# registered_street_name                                     Townline
# registered_street_type                                           Rd
# registered_street_suffix                                        NaN
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  01/14/1923
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            04/05/2016
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3912205
# voter_guid                     5e97f066-0105-11e2-b7e8-cb08ec46562c
# county_file_id_y                                                NaN
# first_name_y                                                  Paula
# last_name_y                                                Anderson
# registered_address_state                                         WI
# registered_address_county                                Washington
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 6, Length: 113, dtype: object
# Unnamed: 0                                                    69411
# nationbuilder_id_x                                          3912733
# state_file_id                                           7.00124e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                               Victoria
# middle_name                                                  Joleen
# last_name_x                                                  Behnke
# suffix                                                          NaN
# email                                   Victoria@Silverlakeauto.Com
# email_opt_in                                                  False
# phone_number                                           920-248-2708
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                          N7648 Little Coffee Rd
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                           Watertown
# registered_county                                         Jefferson
# registered_state                                                 WI
# registered_zip                                           53094-9579
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                      N7648
# registered_street_prefix                                        NaN
# registered_street_name                                Little Coffee
# registered_street_type                                           Rd
# registered_street_suffix                                        NaN
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  02/24/1957
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            04/05/2016
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3912733
# voter_guid                     5f76ba08-0105-11e2-beec-67d16b37689c
# county_file_id_y                                                NaN
# first_name_y                                               Victoria
# last_name_y                                                  Behnke
# registered_address_state                                         WI
# registered_address_county                                 Jefferson
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 7, Length: 113, dtype: object
# Unnamed: 0                                                    69425
# nationbuilder_id_x                                          3912951
# state_file_id                                           7.00234e+08
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                               Margaret
# middle_name                                                    Mary
# last_name_x                                                   Teske
# suffix                                                          NaN
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                           262-365-6600
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                              True
# registered_address1                                  6090 Scenic Dr
# registered_address2                                             NaN
# registered_address3                                             NaN
# registered_city                                           West Bend
# registered_county                                        Washington
# registered_state                                                 WI
# registered_zip                                           53095-4416
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                       6090
# registered_street_prefix                                        NaN
# registered_street_name                                       Scenic
# registered_street_type                                           Dr
# registered_street_suffix                                        NaN
# registered_unit_number                                          NaN
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                  07/20/1943
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            04/04/2006
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                    True
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3912951
# voter_guid                     f260014a-0104-11e2-bf46-5b92cc185181
# county_file_id_y                                                NaN
# first_name_y                                               Margaret
# last_name_y                                                   Teske
# registered_address_state                                         WI
# registered_address_county                                Washington
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                            voted
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 8, Length: 113, dtype: object
# Unnamed: 0                                                    69451
# nationbuilder_id_x                                          3914214
# state_file_id                                           3.18220e+07
# county_file_id_x                                                NaN
# prefix                                                          NaN
# first_name_x                                                 Arnold
# middle_name                                                    Carl
# last_name_x                                              Eidenshink
# suffix                                                           Sr
# email                                                           NaN
# email_opt_in                                                  False
# phone_number                                           920-390-4446
# do_not_call                                                   False
# do_not_contact                                                False
# federal_donotcall                                             False
# registered_address1                                1408 Memorial Dr
# registered_address2                                         Apt 201
# registered_address3                                             NaN
# registered_city                                           Watertown
# registered_county                                             Dodge
# registered_state                                                 WI
# registered_zip                                           53098-3426
# registered_country_code                                         NaN
# registered_country                                              NaN
# registered_street_number                                       1408
# registered_street_prefix                                        NaN
# registered_street_name                                     Memorial
# registered_street_type                                           Dr
# registered_street_suffix                                        NaN
# registered_unit_number                                          201
#                                                ...
# ethnicity                                                       NaN
# language                                                        NaN
# religion                                                        NaN
# church                                                          NaN
# born_at                                                         NaN
# is_deceased                                                   False
# party                                                           NaN
# previous_party                                                  NaN
# inferred_party                                                  NaN
# party_member                                                    NaN
# registered_at                                            03/02/2016
# is_active_voter                                                True
# is_early_voter                                                False
# is_absentee_voter                                             False
# is_permanent_absentee_voter                                   False
# support_probability_score                                       NaN
# turnout_probability_score                                       NaN
# nationbuilder_id_y                                          3914214
# voter_guid                     00df680a-0105-11e2-9d8d-abec58749aaf
# county_file_id_y                                                NaN
# first_name_y                                                 Arnold
# last_name_y                                              Eidenshink
# registered_address_state                                         WI
# registered_address_county                                     Dodge
# election_country                                                 US
# election_state                                                   WI
# election_at                                              2016-11-08
# ballot_vote_method                                         absentee
# ballot_party                                                    NaN
# ballot_cast_at                                                  NaN
# Name: 9, Length: 113, dtype: object

# %%
locations = []
for elem in addresses:
    locValue = gMap.geocode(elem)
    try:
        latLong = locValue[0]['geometry']['location']
        loc = (latLong['lat'],latLong['lng'])
        locations.append(loc)
    except IndexError:
        continue
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-51-912ba4b85eca> in <module>()
#       1 locations = []
#       2 for elem in addresses:
# ----> 3     locValue = gMap.geocode(elem)
#       4     try:
#       5         latLong = locValue[0]['geometry']['location']
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# ~\Anaconda3\lib\site-packages\googlemaps\geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     201         elapsed = datetime.now() - first_request_time
#     202         if elapsed > self.retry_timeout:
# --> 203             raise googlemaps.exceptions.Timeout()
#     204
#     205         if retry_counter > 0:
#
# Timeout:

# %%
locations = np.asarray(locations)
addressFile = open('addresses.csv', 'w')
for elem in addresses:
    addressFile.write("%s\n" %elem)

# %%
addresses
# Out:
#       Unnamed: 0                     address         city state          zip  \
# 0              0      17285 W River Birch Dr   Brookfield    WI   53045-3483
# 1              1               450 S Lake St   Hustisford    WI   53034-9765
# 2              2            5397 County Rd E      Slinger    WI        53086
# 3              3                840 Park Way    Delafield    WI        53018
# 4              4         291 N Fraternity Ln   Whitewater    WI   53190-1251
# 5              5           1409 Wedgewood Dr    Watertown    WI   53098-3406
# 6              6            7406 Townline Rd    West Bend    WI        53090
# 7              7      N7648 Little Coffee Rd    Watertown    WI   53094-9579
# 8              8              6090 Scenic Dr    West Bend    WI   53095-4416
# 9              9            1408 Memorial Dr    Watertown    WI   53098-3426
# 10            10     5021 S Falcon Glen Blvd   Greenfield    WI   53228-3145
# 11            11              135 S East Ave     Waukesha    WI   53186-6207
# 12            12         258 E Washington St    Jefferson    WI   53549-1774
# 13            13            908 Fox Creek Dr    Watertown    WI   53098-1310
# 14            14             901 W Starin Rd   Whitewater    WI   53190-1102
# 15            15          1121 W Carriage Dr   Whitewater    WI   53190-1291
# 16            16   8528 W Watertown Plank Rd    Wauwatosa    WI        53226
# 17            17             2220 N 102Nd St    Wauwatosa    WI   53226-2418
# 18            18             2435 N 111Th St    Wauwatosa    WI   53226-1252
# 19            19      W140N10595 F D Lac Ave   Germantown    WI   53022-4324
# 20            20      5055 High On A Hill Dr     Hubertus    WI   53033-9750
# 21            21        6100 W Stonehedge Dr   Greenfield    WI   53220-4602
# 22            22                     2159 63   West Allis    WI        53219
# 23            23          612 Waters Edge Dr   Whitewater    WI   53190-2215
# 24            24             1450 S 116Th St   West Allis    WI   53214-5507
# 25            25  N17W30195 Crooked Creek Rd     Pewaukee    WI   53072-4899
# 26            26            1491 Hillside Rd     Hubertus    WI   53033-9793
# 27            27             6882 Crooked Rd     Hartford    WI   53027-9443
# 28            28             6100 W State St    Wauwatosa    WI   53213-2990
# 29            29      W120 Court Kathleen St     Sullivan    WI   53178-9712
# ...          ...                         ...          ...   ...          ...
# 67446      67443             2731 S 126Th St   New Berlin    WI   53151-4017
# 67447      67444        21440 W Lawnsdale Ct   New Berlin    WI   53146-3843
# 67448      67445            567 Hartridge Dr     Hartland    WI   53029-2659
# 67449      67446         1001 N Pinegrove Ct     Hartland    WI   53029-8634
# 67450      67447               655 Surrey Ln     Hartland    WI   53029-2529
# 67451      67448           400 Sunnyslope Dr     Hartland    WI   53029-1416
# 67452      67449        605 Cedar Bluffs Way      Slinger    WI   53086-9096
# 67453      67450                600 Creek Rd    West Bend    WI   53090-5475
# 67454      67451            555 Veterans Ave    West Bend    WI   53090-2570
# 67455      67452          N168W21700 Main St      Jackson    WI   53037-9305
# 67456      67453          N168W20866 Main St      Jackson    WI   53037-9462
# 67457      67454      N169W19872 Gorgetwn Dr      Jackson    WI   53037-9468
# 67458      67455     W197N17023 Stonewall Dr      Jackson    WI   53037-9120
# 67459      67456  W195N17353 English Oaks Dr      Jackson    WI   53037-9130
# 67460      67457      W198N16934 Ridgeway Dr      Jackson    WI   53037-9607
# 67461      67458        W207N16211 Elliot Dr      Jackson    WI   53037-8940
# 67462      67459          N161W20732 Kami Ln      Jackson    WI   53037-8938
# 67463      67460       825 Prairie Garden Dr     Kewaskum    WI        53040
# 67464      67461             927 Roseland Dr     Kewaskum    WI   53040-9036
# 67465      67462         631 E Washington St      Slinger    WI   53086-9622
# 67466      67463              504 Drumlin Cv      Slinger    WI   53086-9445
# 67467      67464          2966 Crosswind Trl      Jackson    WI        53037
# 67468      67465            219 Killarney Rd     Hartford    WI   53027-9739
# 67469      67466         7211 W Waterford Rd     Hartford    WI   53027-9782
# 67470      67467               2593 Ridge Rd     Kewaskum    WI   53040-8701
# 67471      67468         8706 W Oklahoma Ave   West Allis    WI   53227-4558
# 67472      67469         8706 W Oklahoma Ave   West Allis    WI   53227-4557
# 67473      67470         2130 Continental Dr    West Bend    WI   53095-7910
# 67474      67471         377 Schraufnagel Dr     Hartland    WI   53029-9403
# 67475      67472       N174W20277 Raymond Rd      Jackson    WI   53037-9004
#
#       Unnamed: 5
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 67446        NaN
# 67447        NaN
# 67448        NaN
# 67449        NaN
# 67450        NaN
# 67451        NaN
# 67452        NaN
# 67453        NaN
# 67454        NaN
# 67455        NaN
# 67456        NaN
# 67457        NaN
# 67458        NaN
# 67459        NaN
# 67460        NaN
# 67461        NaN
# 67462        NaN
# 67463        NaN
# 67464        NaN
# 67465        NaN
# 67466        NaN
# 67467        NaN
# 67468        NaN
# 67469        NaN
# 67470        NaN
# 67471        NaN
# 67472        NaN
# 67473        NaN
# 67474        NaN
# 67475        NaN
#
# [67476 rows x 6 columns]
